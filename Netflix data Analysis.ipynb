# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns
import warnings
warnings.filterwarnings("ignore")

# %%
df = pd.read_csv('netflix1.csv')
df
# Out:
#      show_id     type                             title         director  \
# 0         s1    Movie              Dick Johnson Is Dead  Kirsten Johnson
# 1         s3  TV Show                         Ganglands  Julien Leclercq
# 2         s6  TV Show                     Midnight Mass    Mike Flanagan
# 3        s14    Movie  Confessions of an Invisible Girl    Bruno Garotti
# 4         s8    Movie                           Sankofa     Haile Gerima
# ...      ...      ...                               ...              ...
# 8785   s8797  TV Show                        Yunus Emre        Not Given
# 8786   s8798  TV Show                         Zak Storm        Not Given
# 8787   s8801  TV Show                Zindagi Gulzar Hai        Not Given
# 8788   s8784  TV Show                              Yoko        Not Given
# 8789   s8786  TV Show                               YOM        Not Given
#
#             country  date_added  release_year rating   duration  \
# ...

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 8790 entries, 0 to 8789
# Data columns (total 10 columns):
#  #   Column        Non-Null Count  Dtype
# ---  ------        --------------  -----
#  0   show_id       8790 non-null   object
#  1   type          8790 non-null   object
#  2   title         8790 non-null   object
#  3   director      8790 non-null   object
#  4   country       8790 non-null   object
#  5   date_added    8790 non-null   object
#  6   release_year  8790 non-null   int64
#  7   rating        8790 non-null   object
#  8   duration      8790 non-null   object
#  9   listed_in     8790 non-null   object
# dtypes: int64(1), object(9)
# memory usage: 686.8+ KB

# %%
df.isnull().sum()
# Out:
# show_id         0
# type            0
# title           0
# director        0
# country         0
# date_added      0
# release_year    0
# rating          0
# duration        0
# listed_in       0
# dtype: int64

# %%
typeofcontent=df['type'].value_counts()
print(typeofcontent)
# Out:
# type
# Movie      6126
# TV Show    2664
# Name: count, dtype: int64

# %%
df['listed_in'] = df['listed_in'].str.split(', ')

df = df.explode('listed_in').reset_index(drop = True)
df.head()
# Out:
#   show_id     type                 title         director        country  \
# 0      s1    Movie  Dick Johnson Is Dead  Kirsten Johnson  United States
# 1      s3  TV Show             Ganglands  Julien Leclercq         France
# 2      s3  TV Show             Ganglands  Julien Leclercq         France
# 3      s3  TV Show             Ganglands  Julien Leclercq         France
# 4      s6  TV Show         Midnight Mass    Mike Flanagan  United States
#
#   date_added  release_year rating  duration               listed_in
# 0  9/25/2021          2020  PG-13    90 min           Documentaries
# 1  9/24/2021          2021  TV-MA  1 Season          Crime TV Shows
# 2  9/24/2021          2021  TV-MA  1 Season  International TV Shows
# 3  9/24/2021          2021  TV-MA  1 Season   TV Action & Adventure
# 4  9/24/2021          2021  TV-MA  1 Season               TV Dramas

# %%
df.nunique()
# Out:
# show_id         8790
# type               2
# title           8787
# director        4528
# country           86
# date_added      1713
# release_year      74
# rating            14
# duration         220
# listed_in         42
# dtype: int64

# %%
sns.catplot(y = 'listed_in' , data = df ,kind = 'count',
             order = df['listed_in'].value_counts().index,
            color = '#4287f5')
plt.title('Category distribution')
plt.show()

# %%
df['release_year'].hist()
plt.title('Release year')
plt.xlabel('year')
plt.ylabel('Frequency')
plt.show()

# %%
ratings=df['rating'].value_counts().reset_index().sort_values(by='count', ascending=False)
plt.pie(ratings['count'][:10], labels=ratings['rating'][:10],
autopct='%.0f%%')
plt.suptitle('Rating on Netflix', fontsize=20)
# Out:
# Text(0.5, 0.98, 'Rating on Netflix')

# %%
top5countries = df['country'].value_counts().reset_index().sort_values(by='count', ascending=False)[:5]
plt.bar(top5countries['country'],top5countries['count'])        
plt.xlabel("Country")
plt.ylabel("Count")
plt.suptitle("Top 5 countries with most content on Netflix")
plt.show()
